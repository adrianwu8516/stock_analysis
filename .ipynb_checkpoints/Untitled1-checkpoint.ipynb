# %%
import matplotlib.pyplot as plt
from sklearn.neural_network import MLPClassifier
import numpy as np
import cv2

# %%
# 清理資料
# 保存模型
# 讀取模型

# %pylab inline
import os
import PIL

def ary_prep(addr):
    digits = []
    labels = []
    img_file = []
    for i in os.listdir(addr):
        if i.endswith('.DS_Store'):
                continue
        for image in os.listdir("{}/{}".format(addr, i)):
            if not image.endswith('.png'):
                continue
            file_path = "{}/{}/{}".format(addr, i, image)
            img = PIL.Image.open(file_path).convert('1')
            digits.append([pixel for pixel in iter(img.getdata())])
            labels.append(i)
            img_file.append(file_path)
    return np.array(digits), labels, img_file
digit_ary, labels, img_file = ary_prep("captcha/model_set")

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(digit_ary)
X_scaled = scaler.transform(digit_ary)
mlp = MLPClassifier(hidden_layer_sizes=(30,30,30), activation='logistic', max_iter=5000)
mlp.fit(X_scaled, labels)

import shutil 
for i in range(0, len(img_file)):
    if not os.path.isdir("captcha/mlp_test_result"):
        os.mkdir("captcha/mlp_test_result")
    # Source path 
    source = image_Test[i]
    if not os.path.isdir("captcha/mlp_test_result/{}".format(predicted[i])):
        os.mkdir("captcha/mlp_test_result/{}".format(predicted[i]))
    number = len(os.listdir("captcha/mlp_test_result/{}".format(predicted[i])))
    # Destination path 
    destination = "captcha/mlp_test_result/{}/{}.png".format(predicted[i], number+1)
    # Copy the content of source to destination 
    shutil.copyfile(source, destination) 
    if image_Test[i].split("/")[2] != predicted[i]:
        print("From: ", image_Test[i], " to -> ", predicted[i])
# Out:
# Populating the interactive namespace from numpy and matplotlib
# //anaconda3/lib/python3.7/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['source', 'number']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"
# From:  captcha/test_set/R/189.png  to ->  F
# From:  captcha/test_set/R/376.png  to ->  8
# From:  captcha/test_set/R/410.png  to ->  3
# From:  captcha/test_set/R/366.png  to ->  K
# From:  captcha/test_set/R/212.png  to ->  T
# From:  captcha/test_set/R/213.png  to ->  L
# From:  captcha/test_set/R/167.png  to ->  K
# From:  captcha/test_set/R/198.png  to ->  N
# From:  captcha/test_set/R/210.png  to ->  F
# From:  captcha/test_set/R/370.png  to ->  P
# From:  captcha/test_set/R/328.png  to ->  K
# From:  captcha/test_set/R/314.png  to ->  N
# From:  captcha/test_set/R/275.png  to ->  F
# From:  captcha/test_set/R/258.png  to ->  Z
# From:  captcha/test_set/R/106.png  to ->  F
# From:  captcha/test_set/R/460.png  to ->  E
# From:  captcha/test_set/R/272.png  to ->  E
# From:  captcha/test_set/R/501.png  to ->  3
# From:  captcha/test_set/R/493.png  to ->  E
# From:  captcha/test_set/R/242.png  to ->  4
# From:  captcha/test_set/R/137.png  to ->  K
# From:  captcha/test_set/R/452.png  to ->  K
# From:  captcha/test_set/R/324.png  to ->  4
# From:  captcha/test_set/R/318.png  to ->  8
# From:  captcha/test_set/R/250.png  to ->  E
# From:  captcha/test_set/R/245.png  to ->  K
# From:  captcha/test_set/R/251.png  to ->  F
# From:  captcha/test_set/R/457.png  to ->  E
# From:  captcha/test_set/R/325.png  to ->  F
# From:  captcha/test_set/R/333.png  to ->  E
# From:  captcha/test_set/R/253.png  to ->  L
# From:  captcha/test_set/R/332.png  to ->  N
# From:  captcha/test_set/R/369.png  to ->  K
# From:  captcha/test_set/R/168.png  to ->  4
# From:  captcha/test_set/R/197.png  to ->  K
# From:  captcha/test_set/R/222.png  to ->  K
# From:  captcha/test_set/R/196.png  to ->  V
# From:  captcha/test_set/R/425.png  to ->  4
# From:  captcha/test_set/R/352.png  to ->  K
# From:  captcha/test_set/R/378.png  to ->  E
# From:  captcha/test_set/R/191.png  to ->  K
# From:  captcha/test_set/R/225.png  to ->  K
# From:  captcha/test_set/R/52.png  to ->  4
# From:  captcha/test_set/U/1145.png  to ->  C
# From:  captcha/test_set/U/1596.png  to ->  A
# From:  captcha/test_set/U/764.png  to ->  6
# From:  captcha/test_set/U/598.png  to ->  A
# From:  captcha/test_set/U/567.png  to ->  Q
# From:  captcha/test_set/U/1540.png  to ->  D
# From:  captcha/test_set/U/956.png  to ->  D
# From:  captcha/test_set/U/1408.png  to ->  J
# From:  captcha/test_set/U/611.png  to ->  N
# From:  captcha/test_set/U/1636.png  to ->  D
# From:  captcha/test_set/U/1150.png  to ->  D
# From:  captcha/test_set/U/997.png  to ->  9
# From:  captcha/test_set/U/1218.png  to ->  D
# From:  captcha/test_set/U/1542.png  to ->  N
# From:  captcha/test_set/U/203.png  to ->  D
# From:  captcha/test_set/U/1754.png  to ->  D
# From:  captcha/test_set/U/1755.png  to ->  J
# From:  captcha/test_set/U/558.png  to ->  D
# From:  captcha/test_set/U/1345.png  to ->  D
# From:  captcha/test_set/U/376.png  to ->  D
# From:  captcha/test_set/U/1190.png  to ->  Q
# From:  captcha/test_set/U/1194.png  to ->  D
# From:  captcha/test_set/U/399.png  to ->  3
# From:  captcha/test_set/U/1553.png  to ->  A
# From:  captcha/test_set/U/978.png  to ->  N
# From:  captcha/test_set/U/1220.png  to ->  A
# From:  captcha/test_set/U/1142.png  to ->  H
# From:  captcha/test_set/U/1431.png  to ->  D
# From:  captcha/test_set/U/1357.png  to ->  D
# From:  captcha/test_set/U/358.png  to ->  N
# From:  captcha/test_set/U/1640.png  to ->  A
# From:  captcha/test_set/U/1126.png  to ->  D
# From:  captcha/test_set/U/854.png  to ->  Q
# From:  captcha/test_set/U/1046.png  to ->  H
# From:  captcha/test_set/U/909.png  to ->  J
# From:  captcha/test_set/U/672.png  to ->  9
# From:  captcha/test_set/U/1050.png  to ->  D
# From:  captcha/test_set/U/922.png  to ->  Q
# From:  captcha/test_set/U/1468.png  to ->  J
# From:  captcha/test_set/U/895.png  to ->  D
# From:  captcha/test_set/U/339.png  to ->  3
# From:  captcha/test_set/U/1493.png  to ->  A
# From:  captcha/test_set/U/846.png  to ->  Q
# From:  captcha/test_set/U/852.png  to ->  Q
# From:  captcha/test_set/U/932.png  to ->  D
# From:  captcha/test_set/U/1041.png  to ->  9
# From:  captcha/test_set/U/264.png  to ->  D
# From:  captcha/test_set/U/702.png  to ->  D
# From:  captcha/test_set/U/925.png  to ->  D
# From:  captcha/test_set/U/1725.png  to ->  N
# From:  captcha/test_set/U/1081.png  to ->  6
# From:  captcha/test_set/U/475.png  to ->  D
# From:  captcha/test_set/U/875.png  to ->  D
# From:  captcha/test_set/U/684.png  to ->  D
# From:  captcha/test_set/U/323.png  to ->  D
# From:  captcha/test_set/U/337.png  to ->  D
# From:  captcha/test_set/U/451.png  to ->  Q
# From:  captcha/test_set/U/137.png  to ->  D
# From:  captcha/test_set/U/651.png  to ->  N
# From:  captcha/test_set/U/1460.png  to ->  D
# From:  captcha/test_set/U/1299.png  to ->  Q
# From:  captcha/test_set/U/1703.png  to ->  A
# From:  captcha/test_set/U/718.png  to ->  V
# From:  captcha/test_set/U/491.png  to ->  D
# From:  captcha/test_set/U/1471.png  to ->  D
# From:  captcha/test_set/U/708.png  to ->  D
# From:  captcha/test_set/U/907.png  to ->  D
# From:  captcha/test_set/U/1048.png  to ->  D
# From:  captcha/test_set/U/1074.png  to ->  A
# From:  captcha/test_set/U/279.png  to ->  D
# From:  captcha/test_set/U/494.png  to ->  D
# From:  captcha/test_set/U/319.png  to ->  D
# From:  captcha/test_set/U/24.png  to ->  Q
# From:  captcha/test_set/U/938.png  to ->  D
# From:  captcha/test_set/U/1738.png  to ->  Q
# From:  captcha/test_set/U/1711.png  to ->  Q
# From:  captcha/test_set/U/1315.png  to ->  4
# From:  captcha/test_set/U/859.png  to ->  N
# From:  captcha/test_set/U/468.png  to ->  D
# From:  captcha/test_set/U/396.png  to ->  A
# From:  captcha/test_set/U/1399.png  to ->  Q
# From:  captcha/test_set/U/631.png  to ->  D
# From:  captcha/test_set/U/962.png  to ->  D
# From:  captcha/test_set/U/792.png  to ->  N
# From:  captcha/test_set/U/547.png  to ->  D
# From:  captcha/test_set/U/1213.png  to ->  D
# From:  captcha/test_set/U/1159.png  to ->  Q
# From:  captcha/test_set/U/424.png  to ->  D
# From:  captcha/test_set/U/1371.png  to ->  N
# From:  captcha/test_set/U/1563.png  to ->  Q
# From:  captcha/test_set/U/1205.png  to ->  J
# From:  captcha/test_set/U/1577.png  to ->  D
# From:  captcha/test_set/U/223.png  to ->  Q
# From:  captcha/test_set/U/1370.png  to ->  9
# From:  captcha/test_set/U/394.png  to ->  Q
# From:  captcha/test_set/U/1166.png  to ->  J
# From:  captcha/test_set/U/1172.png  to ->  N
# From:  captcha/test_set/U/1628.png  to ->  Q
# From:  captcha/test_set/U/435.png  to ->  D
# From:  captcha/test_set/U/353.png  to ->  A
# From:  captcha/test_set/U/637.png  to ->  Q
# From:  captcha/test_set/U/757.png  to ->  D
# From:  captcha/test_set/U/1572.png  to ->  J
# From:  captcha/test_set/U/1228.png  to ->  Q
# From:  captcha/test_set/U/582.png  to ->  D
# From:  captcha/test_set/U/150.png  to ->  A
# From:  captcha/test_set/U/1822.png  to ->  N
# From:  captcha/test_set/U/1808.png  to ->  D
# From:  captcha/test_set/U/1834.png  to ->  D
# From:  captcha/test_set/U/1161.png  to ->  3
# From:  captcha/test_set/U/1613.png  to ->  9
# From:  captcha/test_set/U/634.png  to ->  D
# From:  captcha/test_set/U/84.png  to ->  9
# From:  captcha/test_set/U/1217.png  to ->  Q
# From:  captcha/test_set/U/1767.png  to ->  D
# From:  captcha/test_set/U/972.png  to ->  D
# From:  captcha/test_set/U/1202.png  to ->  C
# From:  captcha/test_set/U/1438.png  to ->  D
# From:  captcha/test_set/U/1410.png  to ->  Q
# From:  captcha/test_set/N/823.png  to ->  U
# From:  captcha/test_set/N/980.png  to ->  D
# From:  captcha/test_set/N/1050.png  to ->  X
# From:  captcha/test_set/N/1120.png  to ->  K
# From:  captcha/test_set/N/715.png  to ->  U
# From:  captcha/test_set/N/516.png  to ->  H
# From:  captcha/test_set/N/104.png  to ->  X
# From:  captcha/test_set/N/879.png  to ->  X
# From:  captcha/test_set/N/296.png  to ->  Q
# From:  captcha/test_set/N/669.png  to ->  U
# From:  captcha/test_set/N/754.png  to ->  X
# From:  captcha/test_set/G/638.png  to ->  U
# From:  captcha/test_set/G/770.png  to ->  3
# From:  captcha/test_set/G/1233.png  to ->  C
# From:  captcha/test_set/G/598.png  to ->  8
# From:  captcha/test_set/G/1385.png  to ->  9
# From:  captcha/test_set/G/639.png  to ->  6
# From:  captcha/test_set/G/1144.png  to ->  6
# From:  captcha/test_set/G/808.png  to ->  3
# From:  captcha/test_set/G/1218.png  to ->  Q
# From:  captcha/test_set/G/1230.png  to ->  6
# From:  captcha/test_set/G/366.png  to ->  8
# From:  captcha/test_set/G/1194.png  to ->  6
# From:  captcha/test_set/G/399.png  to ->  6
# From:  captcha/test_set/G/1433.png  to ->  9
# From:  captcha/test_set/G/776.png  to ->  6
# From:  captcha/test_set/G/762.png  to ->  3
# From:  captcha/test_set/G/992.png  to ->  J
# From:  captcha/test_set/G/1553.png  to ->  Q
# From:  captcha/test_set/G/548.png  to ->  C
# From:  captcha/test_set/G/549.png  to ->  6
# From:  captcha/test_set/G/944.png  to ->  8
# From:  captcha/test_set/G/1354.png  to ->  7
# From:  captcha/test_set/G/818.png  to ->  Q
# From:  captcha/test_set/G/398.png  to ->  3
# From:  captcha/test_set/G/1181.png  to ->  C
# From:  captcha/test_set/G/1424.png  to ->  9
# From:  captcha/test_set/G/946.png  to ->  3
# From:  captcha/test_set/G/1035.png  to ->  6
# From:  captcha/test_set/G/947.png  to ->  3
# From:  captcha/test_set/G/364.png  to ->  8
# From:  captcha/test_set/G/667.png  to ->  3
# From:  captcha/test_set/G/868.png  to ->  9
# From:  captcha/test_set/G/1442.png  to ->  3
# From:  captcha/test_set/G/1456.png  to ->  9
# From:  captcha/test_set/G/934.png  to ->  9
# From:  captcha/test_set/G/908.png  to ->  6
# From:  captcha/test_set/G/1053.png  to ->  8
# From:  captcha/test_set/G/504.png  to ->  6
# From:  captcha/test_set/G/1292.png  to ->  C
# From:  captcha/test_set/G/869.png  to ->  3
# From:  captcha/test_set/G/896.png  to ->  9
# From:  captcha/test_set/G/316.png  to ->  8
# From:  captcha/test_set/G/472.png  to ->  C
# From:  captcha/test_set/G/314.png  to ->  3
# From:  captcha/test_set/G/670.png  to ->  3
# From:  captcha/test_set/G/1441.png  to ->  3
# From:  captcha/test_set/G/710.png  to ->  C
# From:  captcha/test_set/G/512.png  to ->  9
# From:  captcha/test_set/G/513.png  to ->  7
# From:  captcha/test_set/G/1252.png  to ->  8
# From:  captcha/test_set/G/488.png  to ->  6
# From:  captcha/test_set/G/846.png  to ->  6
# From:  captcha/test_set/G/852.png  to ->  6
# From:  captcha/test_set/G/715.png  to ->  3
# From:  captcha/test_set/G/1054.png  to ->  3
# From:  captcha/test_set/G/1525.png  to ->  8
# From:  captcha/test_set/G/700.png  to ->  4
# From:  captcha/test_set/G/890.png  to ->  C
# From:  captcha/test_set/G/1486.png  to ->  3
# From:  captcha/test_set/G/1335.png  to ->  Q
# From:  captcha/test_set/G/689.png  to ->  3
# From:  captcha/test_set/G/919.png  to ->  E
# From:  captcha/test_set/G/500.png  to ->  6
# From:  captcha/test_set/G/930.png  to ->  3
# From:  captcha/test_set/G/1532.png  to ->  6
# From:  captcha/test_set/G/38.png  to ->  A
# From:  captcha/test_set/G/1491.png  to ->  D
# From:  captcha/test_set/G/313.png  to ->  C
# From:  captcha/test_set/G/322.png  to ->  3
# From:  captcha/test_set/G/685.png  to ->  8
# From:  captcha/test_set/G/518.png  to ->  C
# From:  captcha/test_set/G/1098.png  to ->  6
# From:  captcha/test_set/G/1264.png  to ->  C
# From:  captcha/test_set/G/733.png  to ->  6
# From:  captcha/test_set/G/1310.png  to ->  9
# From:  captcha/test_set/G/337.png  to ->  9
# From:  captcha/test_set/G/321.png  to ->  9
# From:  captcha/test_set/G/335.png  to ->  8
# From:  captcha/test_set/G/484.png  to ->  8
# From:  captcha/test_set/G/1104.png  to ->  A
# From:  captcha/test_set/G/679.png  to ->  8
# From:  captcha/test_set/G/1474.png  to ->  6
# From:  captcha/test_set/G/1272.png  to ->  6
# From:  captcha/test_set/G/693.png  to ->  3
# From:  captcha/test_set/G/1307.png  to ->  8
# From:  captcha/test_set/G/877.png  to ->  6
# From:  captcha/test_set/G/1061.png  to ->  9
# From:  captcha/test_set/G/1049.png  to ->  C
# From:  captcha/test_set/G/1538.png  to ->  6
# From:  captcha/test_set/G/1510.png  to ->  C
# From:  captcha/test_set/G/1100.png  to ->  6
# From:  captcha/test_set/G/455.png  to ->  9
# From:  captcha/test_set/G/657.png  to ->  8
# From:  captcha/test_set/G/643.png  to ->  3
# From:  captcha/test_set/G/1512.png  to ->  6
# From:  captcha/test_set/G/1248.png  to ->  Q
# From:  captcha/test_set/G/905.png  to ->  6
# From:  captcha/test_set/G/1513.png  to ->  C
# From:  captcha/test_set/G/1467.png  to ->  9
# From:  captcha/test_set/G/468.png  to ->  6
# From:  captcha/test_set/G/326.png  to ->  6
# From:  captcha/test_set/G/1158.png  to ->  C
# From:  captcha/test_set/G/382.png  to ->  Q
# From:  captcha/test_set/G/745.png  to ->  6
# From:  captcha/test_set/G/1548.png  to ->  3
# From:  captcha/test_set/G/618.png  to ->  C
# From:  captcha/test_set/G/1398.png  to ->  3
# From:  captcha/test_set/G/154.png  to ->  3
# From:  captcha/test_set/G/746.png  to ->  8
# From:  captcha/test_set/G/949.png  to ->  C
# From:  captcha/test_set/G/1012.png  to ->  6
# From:  captcha/test_set/G/592.png  to ->  6
# From:  captcha/test_set/G/545.png  to ->  J
# From:  captcha/test_set/G/579.png  to ->  3
# From:  captcha/test_set/G/1416.png  to ->  9
# From:  captcha/test_set/G/633.png  to ->  6
# From:  captcha/test_set/G/409.png  to ->  C
# From:  captcha/test_set/G/151.png  to ->  U
# From:  captcha/test_set/G/804.png  to ->  3
# From:  captcha/test_set/G/743.png  to ->  3
# From:  captcha/test_set/G/970.png  to ->  6
# From:  captcha/test_set/G/964.png  to ->  D
# From:  captcha/test_set/G/582.png  to ->  9
# From:  captcha/test_set/G/583.png  to ->  C
# From:  captcha/test_set/G/959.png  to ->  3
# From:  captcha/test_set/G/1407.png  to ->  6
# From:  captcha/test_set/G/1163.png  to ->  9
# From:  captcha/test_set/G/146.png  to ->  D
# From:  captcha/test_set/G/608.png  to ->  Q
# From:  captcha/test_set/G/1217.png  to ->  3
# From:  captcha/test_set/G/967.png  to ->  6
# From:  captcha/test_set/G/1559.png  to ->  6
# From:  captcha/test_set/G/1000.png  to ->  3
# From:  captcha/test_set/G/423.png  to ->  9
# From:  captcha/test_set/Z/837.png  to ->  2
# From:  captcha/test_set/Z/980.png  to ->  3
# From:  captcha/test_set/Z/1569.png  to ->  R
# From:  captcha/test_set/Z/200.png  to ->  2
# From:  captcha/test_set/Z/1554.png  to ->  2
# From:  captcha/test_set/Z/1583.png  to ->  2
# From:  captcha/test_set/Z/995.png  to ->  2
# From:  captcha/test_set/Z/759.png  to ->  2
# From:  captcha/test_set/Z/1352.png  to ->  2
# From:  captcha/test_set/Z/1622.png  to ->  2
# From:  captcha/test_set/Z/407.png  to ->  2
# From:  captcha/test_set/Z/1187.png  to ->  2
# From:  captcha/test_set/Z/1620.png  to ->  2
# From:  captcha/test_set/Z/607.png  to ->  7
# From:  captcha/test_set/Z/1378.png  to ->  2
# From:  captcha/test_set/Z/1436.png  to ->  2
# From:  captcha/test_set/Z/997.png  to ->  7
# From:  captcha/test_set/Z/983.png  to ->  2
# From:  captcha/test_set/Z/1542.png  to ->  2
# From:  captcha/test_set/Z/559.png  to ->  2
# From:  captcha/test_set/Z/941.png  to ->  7
# From:  captcha/test_set/Z/1219.png  to ->  2
# From:  captcha/test_set/Z/1621.png  to ->  2
# From:  captcha/test_set/Z/389.png  to ->  7
# From:  captcha/test_set/Z/1190.png  to ->  2
# From:  captcha/test_set/Z/1341.png  to ->  2
# From:  captcha/test_set/Z/65.png  to ->  2
# From:  captcha/test_set/Z/776.png  to ->  2
# From:  captcha/test_set/Z/762.png  to ->  2
# From:  captcha/test_set/Z/992.png  to ->  7
# From:  captcha/test_set/Z/944.png  to ->  2
# From:  captcha/test_set/Z/1591.png  to ->  2
# From:  captcha/test_set/Z/617.png  to ->  2
# From:  captcha/test_set/Z/165.png  to ->  2
# From:  captcha/test_set/Z/1197.png  to ->  2
# From:  captcha/test_set/Z/601.png  to ->  2
# From:  captcha/test_set/Z/99.png  to ->  2
# From:  captcha/test_set/Z/749.png  to ->  2
# From:  captcha/test_set/Z/1222.png  to ->  2
# From:  captcha/test_set/Z/984.png  to ->  2
# From:  captcha/test_set/Z/760.png  to ->  2
# From:  captcha/test_set/Z/67.png  to ->  2
# From:  captcha/test_set/Z/600.png  to ->  2
# From:  captcha/test_set/Z/1196.png  to ->  2
# From:  captcha/test_set/Z/364.png  to ->  2
# From:  captcha/test_set/Z/471.png  to ->  7
# From:  captcha/test_set/Z/854.png  to ->  7
# From:  captcha/test_set/Z/1442.png  to ->  2
# From:  captcha/test_set/Z/920.png  to ->  2
# From:  captcha/test_set/Z/934.png  to ->  2
# From:  captcha/test_set/Z/1536.png  to ->  2
# From:  captcha/test_set/Z/908.png  to ->  2
# From:  captcha/test_set/Z/1047.png  to ->  7
# From:  captcha/test_set/Z/464.png  to ->  2
# From:  captcha/test_set/Z/314.png  to ->  2
# From:  captcha/test_set/Z/116.png  to ->  2
# From:  captcha/test_set/Z/857.png  to ->  2
# From:  captcha/test_set/Z/17.png  to ->  2
# From:  captcha/test_set/Z/1333.png  to ->  2
# From:  captcha/test_set/Z/1441.png  to ->  2
# From:  captcha/test_set/Z/1509.png  to ->  2
# From:  captcha/test_set/Z/1086.png  to ->  2
# From:  captcha/test_set/Z/1092.png  to ->  2
# From:  captcha/test_set/Z/1093.png  to ->  2
# From:  captcha/test_set/Z/1087.png  to ->  2
# From:  captcha/test_set/Z/1285.png  to ->  2
# From:  captcha/test_set/Z/739.png  to ->  2
# From:  captcha/test_set/Z/842.png  to ->  2
# From:  captcha/test_set/Z/665.png  to ->  2
# From:  captcha/test_set/Z/1118.png  to ->  2
# From:  captcha/test_set/Z/305.png  to ->  2
# From:  captcha/test_set/Z/339.png  to ->  E
# From:  captcha/test_set/Z/1336.png  to ->  2
# From:  captcha/test_set/Z/1322.png  to ->  2
# From:  captcha/test_set/Z/715.png  to ->  7
# From:  captcha/test_set/Z/926.png  to ->  2
# From:  captcha/test_set/Z/265.png  to ->  2
# From:  captcha/test_set/Z/1096.png  to ->  2
# From:  captcha/test_set/Z/13.png  to ->  2
# From:  captcha/test_set/Z/847.png  to ->  2
# From:  captcha/test_set/Z/1109.png  to ->  2
# From:  captcha/test_set/Z/462.png  to ->  T
# From:  captcha/test_set/Z/1123.png  to ->  2
# From:  captcha/test_set/Z/716.png  to ->  2
# From:  captcha/test_set/Z/1241.png  to ->  2
# From:  captcha/test_set/Z/272.png  to ->  7
# From:  captcha/test_set/Z/1042.png  to ->  2
# From:  captcha/test_set/Z/893.png  to ->  2
# From:  captcha/test_set/Z/1491.png  to ->  2
# From:  captcha/test_set/Z/1136.png  to ->  2
# From:  captcha/test_set/Z/449.png  to ->  7
# From:  captcha/test_set/Z/450.png  to ->  7
# From:  captcha/test_set/Z/875.png  to ->  2
# From:  captcha/test_set/Z/1339.png  to ->  2
# From:  captcha/test_set/Z/1259.png  to ->  2
# From:  captcha/test_set/Z/915.png  to ->  2
# From:  captcha/test_set/Z/929.png  to ->  2
# From:  captcha/test_set/Z/518.png  to ->  2
# From:  captcha/test_set/Z/524.png  to ->  2
# From:  captcha/test_set/Z/848.png  to ->  2
# From:  captcha/test_set/Z/20.png  to ->  2
# From:  captcha/test_set/Z/653.png  to ->  2
# From:  captcha/test_set/Z/335.png  to ->  2
# From:  captcha/test_set/Z/719.png  to ->  2
# From:  captcha/test_set/Z/255.png  to ->  2
# From:  captcha/test_set/Z/1064.png  to ->  2
# From:  captcha/test_set/Z/1273.png  to ->  2
# From:  captcha/test_set/Z/718.png  to ->  2
# From:  captcha/test_set/Z/1475.png  to ->  2
# From:  captcha/test_set/Z/863.png  to ->  2
# From:  captcha/test_set/Z/906.png  to ->  2
# From:  captcha/test_set/Z/1289.png  to ->  2
# From:  captcha/test_set/Z/721.png  to ->  2
# From:  captcha/test_set/Z/441.png  to ->  2
# From:  captcha/test_set/Z/1466.png  to ->  2
# From:  captcha/test_set/Z/1314.png  to ->  2
# From:  captcha/test_set/Z/938.png  to ->  2
# From:  captcha/test_set/Z/290.png  to ->  2
# From:  captcha/test_set/Z/1275.png  to ->  3
# From:  captcha/test_set/Z/722.png  to ->  2
# From:  captcha/test_set/Z/31.png  to ->  2
# From:  captcha/test_set/Z/1467.png  to ->  2
# From:  captcha/test_set/Z/1301.png  to ->  2
# From:  captcha/test_set/Z/656.png  to ->  2
# From:  captcha/test_set/Z/341.png  to ->  2
# From:  captcha/test_set/Z/1158.png  to ->  2
# From:  captcha/test_set/Z/1602.png  to ->  2
# From:  captcha/test_set/Z/619.png  to ->  2
# From:  captcha/test_set/Z/1428.png  to ->  2
# From:  captcha/test_set/Z/1574.png  to ->  7
# From:  captcha/test_set/Z/792.png  to ->  2
# From:  captcha/test_set/Z/546.png  to ->  2
# From:  captcha/test_set/Z/1549.png  to ->  2
# From:  captcha/test_set/Z/778.png  to ->  2
# From:  captcha/test_set/Z/803.png  to ->  2
# From:  captcha/test_set/Z/397.png  to ->  2
# From:  captcha/test_set/Z/168.png  to ->  2
# From:  captcha/test_set/Z/1403.png  to ->  2
# From:  captcha/test_set/Z/1205.png  to ->  2
# From:  captcha/test_set/Z/1211.png  to ->  7
# From:  captcha/test_set/Z/1013.png  to ->  2
# From:  captcha/test_set/Z/790.png  to ->  2
# From:  captcha/test_set/Z/974.png  to ->  2
# From:  captcha/test_set/Z/68.png  to ->  2
# From:  captcha/test_set/Z/627.png  to ->  2
# From:  captcha/test_set/Z/169.png  to ->  2
# From:  captcha/test_set/Z/179.png  to ->  2
# From:  captcha/test_set/Z/1599.png  to ->  2
# From:  captcha/test_set/Z/958.png  to ->  2
# From:  captcha/test_set/Z/597.png  to ->  2
# From:  captcha/test_set/Z/232.png  to ->  2
# From:  captcha/test_set/Z/971.png  to ->  7
# From:  captcha/test_set/Z/781.png  to ->  2
# From:  captcha/test_set/Z/811.png  to ->  2
# From:  captcha/test_set/Z/187.png  to ->  2
# From:  captcha/test_set/Z/178.png  to ->  2
# From:  captcha/test_set/Z/1163.png  to ->  2
# From:  captcha/test_set/Z/1175.png  to ->  2
# From:  captcha/test_set/Z/146.png  to ->  2
# From:  captcha/test_set/Z/1363.png  to ->  7
# From:  captcha/test_set/Z/797.png  to ->  2
# From:  captcha/test_set/Z/1559.png  to ->  2
# From:  captcha/test_set/Z/769.png  to ->  2
# From:  captcha/test_set/Z/755.png  to ->  2
# From:  captcha/test_set/Z/1438.png  to ->  2
# From:  captcha/test_set/Z/1612.png  to ->  7
# From:  captcha/test_set/Z/1160.png  to ->  2
# From:  captcha/test_set/T/994.png  to ->  7
# From:  captcha/test_set/T/764.png  to ->  7
# From:  captcha/test_set/T/572.png  to ->  7
# From:  captcha/test_set/T/1540.png  to ->  7
# From:  captcha/test_set/T/1232.png  to ->  7
# From:  captcha/test_set/T/605.png  to ->  Z
# From:  captcha/test_set/T/361.png  to ->  X
# From:  captcha/test_set/T/1813.png  to ->  7
# From:  captcha/test_set/T/388.png  to ->  7
# From:  captcha/test_set/T/1422.png  to ->  7
# From:  captcha/test_set/T/767.png  to ->  7
# From:  captcha/test_set/T/1218.png  to ->  Z
# From:  captcha/test_set/T/798.png  to ->  Z
# From:  captcha/test_set/T/940.png  to ->  7
# From:  captcha/test_set/T/1556.png  to ->  2
# From:  captcha/test_set/T/1026.png  to ->  Z
# From:  captcha/test_set/T/955.png  to ->  7
# From:  captcha/test_set/T/766.png  to ->  Y
# From:  captcha/test_set/T/1594.png  to ->  Z
# From:  captcha/test_set/T/982.png  to ->  7
# From:  captcha/test_set/T/1386.png  to ->  7
# From:  captcha/test_set/T/158.png  to ->  Z
# From:  captcha/test_set/T/951.png  to ->  7
# From:  captcha/test_set/T/1022.png  to ->  Y
# From:  captcha/test_set/T/950.png  to ->  7
# From:  captcha/test_set/T/1368.png  to ->  7
# From:  captcha/test_set/T/159.png  to ->  7
# From:  captcha/test_set/T/1383.png  to ->  7
# From:  captcha/test_set/T/1397.png  to ->  7
# From:  captcha/test_set/T/417.png  to ->  Z
# From:  captcha/test_set/T/1424.png  to ->  7
# From:  captcha/test_set/T/1035.png  to ->  7
# From:  captcha/test_set/T/562.png  to ->  X
# From:  captcha/test_set/T/1223.png  to ->  Z
# From:  captcha/test_set/T/990.png  to ->  7
# From:  captcha/test_set/T/1586.png  to ->  Z
# From:  captcha/test_set/T/1592.png  to ->  7
# From:  captcha/test_set/T/1394.png  to ->  Y
# From:  captcha/test_set/T/1169.png  to ->  7
# From:  captcha/test_set/T/1828.png  to ->  X
# From:  captcha/test_set/T/1654.png  to ->  X
# From:  captcha/test_set/T/897.png  to ->  7
# From:  captcha/test_set/T/883.png  to ->  7
# From:  captcha/test_set/T/14.png  to ->  7
# From:  captcha/test_set/T/1456.png  to ->  L
# From:  captcha/test_set/T/1287.png  to ->  Y
# From:  captcha/test_set/T/1278.png  to ->  X
# From:  captcha/test_set/T/276.png  to ->  7
# From:  captcha/test_set/T/935.png  to ->  X
# From:  captcha/test_set/T/1319.png  to ->  7
# From:  captcha/test_set/T/1494.png  to ->  Q
# From:  captcha/test_set/T/1655.png  to ->  7
# From:  captcha/test_set/T/1127.png  to ->  L
# From:  captcha/test_set/T/1694.png  to ->  H
# From:  captcha/test_set/T/472.png  to ->  7
# From:  captcha/test_set/T/1858.png  to ->  Z
# From:  captcha/test_set/T/1131.png  to ->  7
# From:  captcha/test_set/T/17.png  to ->  7
# From:  captcha/test_set/T/1455.png  to ->  7
# From:  captcha/test_set/T/704.png  to ->  7
# From:  captcha/test_set/T/274.png  to ->  Z
# From:  captcha/test_set/T/506.png  to ->  X
# From:  captcha/test_set/T/260.png  to ->  X
# From:  captcha/test_set/T/1723.png  to ->  Z
# From:  captcha/test_set/T/922.png  to ->  Z
# From:  captcha/test_set/T/936.png  to ->  L
# From:  captcha/test_set/T/1440.png  to ->  7
# From:  captcha/test_set/T/1468.png  to ->  7
# From:  captcha/test_set/T/1118.png  to ->  Z
# From:  captcha/test_set/T/311.png  to ->  7
# From:  captcha/test_set/T/649.png  to ->  7
# From:  captcha/test_set/T/1478.png  to ->  X
# From:  captcha/test_set/T/1524.png  to ->  7
# From:  captcha/test_set/T/503.png  to ->  7
# From:  captcha/test_set/T/1733.png  to ->  7
# From:  captcha/test_set/T/1479.png  to ->  3
# From:  captcha/test_set/T/884.png  to ->  7
# From:  captcha/test_set/T/1684.png  to ->  7
# From:  captcha/test_set/T/1690.png  to ->  7
# From:  captcha/test_set/T/460.png  to ->  2
# From:  captcha/test_set/T/662.png  to ->  7
# From:  captcha/test_set/T/886.png  to ->  7
# From:  captcha/test_set/T/1335.png  to ->  Z
# From:  captcha/test_set/T/1309.png  to ->  Y
# From:  captcha/test_set/T/1526.png  to ->  7
# From:  captcha/test_set/T/1678.png  to ->  Z
# From:  captcha/test_set/T/478.png  to ->  4
# From:  captcha/test_set/T/1649.png  to ->  Z
# From:  captcha/test_set/T/524.png  to ->  7
# From:  captcha/test_set/T/256.png  to ->  X
# From:  captcha/test_set/T/1729.png  to ->  X
# From:  captcha/test_set/T/1728.png  to ->  X
# From:  captcha/test_set/T/531.png  to ->  N
# From:  captcha/test_set/T/243.png  to ->  X
# From:  captcha/test_set/T/519.png  to ->  Z
# From:  captcha/test_set/T/874.png  to ->  V
# From:  captcha/test_set/T/451.png  to ->  7
# From:  captcha/test_set/T/321.png  to ->  7
# From:  captcha/test_set/T/447.png  to ->  2
# From:  captcha/test_set/T/889.png  to ->  L
# From:  captcha/test_set/T/876.png  to ->  R
# From:  captcha/test_set/T/731.png  to ->  Z
# From:  captcha/test_set/T/1501.png  to ->  7
# From:  captcha/test_set/T/687.png  to ->  Z
# From:  captcha/test_set/T/37.png  to ->  7
# From:  captcha/test_set/T/485.png  to ->  7
# From:  captcha/test_set/T/334.png  to ->  X
# From:  captcha/test_set/T/456.png  to ->  Z
# From:  captcha/test_set/T/318.png  to ->  7
# From:  captcha/test_set/T/1667.png  to ->  R
# From:  captcha/test_set/T/1129.png  to ->  7
# From:  captcha/test_set/T/898.png  to ->  7
# From:  captcha/test_set/T/244.png  to ->  Z
# From:  captcha/test_set/T/1706.png  to ->  7
# From:  captcha/test_set/T/245.png  to ->  X
# From:  captcha/test_set/T/709.png  to ->  7
# From:  captcha/test_set/T/26.png  to ->  7
# From:  captcha/test_set/T/696.png  to ->  X
# From:  captcha/test_set/T/480.png  to ->  Z
# From:  captcha/test_set/T/1114.png  to ->  7
# From:  captcha/test_set/T/1499.png  to ->  7
# From:  captcha/test_set/T/1062.png  to ->  X
# From:  captcha/test_set/T/1738.png  to ->  L
# From:  captcha/test_set/T/1705.png  to ->  Z
# From:  captcha/test_set/T/520.png  to ->  7
# From:  captcha/test_set/T/1513.png  to ->  L
# From:  captcha/test_set/T/939.png  to ->  7
# From:  captcha/test_set/T/681.png  to ->  Z
# From:  captcha/test_set/T/859.png  to ->  7
# From:  captcha/test_set/T/355.png  to ->  2
# From:  captcha/test_set/T/1428.png  to ->  X
# From:  captcha/test_set/T/792.png  to ->  Z
# From:  captcha/test_set/T/209.png  to ->  Z
# From:  captcha/test_set/T/590.png  to ->  Z
# From:  captcha/test_set/T/585.png  to ->  Z
# From:  captcha/test_set/T/1213.png  to ->  Z
# From:  captcha/test_set/T/977.png  to ->  7
# From:  captcha/test_set/T/803.png  to ->  7
# From:  captcha/test_set/T/1171.png  to ->  X
# From:  captcha/test_set/T/1818.png  to ->  7
# From:  captcha/test_set/T/354.png  to ->  R
# From:  captcha/test_set/T/1824.png  to ->  7
# From:  captcha/test_set/T/424.png  to ->  X
# From:  captcha/test_set/T/1615.png  to ->  7
# From:  captcha/test_set/T/1601.png  to ->  7
# From:  captcha/test_set/T/626.png  to ->  7
# From:  captcha/test_set/T/801.png  to ->  V
# From:  captcha/test_set/T/236.png  to ->  7
# From:  captcha/test_set/T/1775.png  to ->  V
# From:  captcha/test_set/T/1006.png  to ->  7
# From:  captcha/test_set/T/237.png  to ->  X
# From:  captcha/test_set/T/1576.png  to ->  Z
# From:  captcha/test_set/T/155.png  to ->  7
# From:  captcha/test_set/T/1628.png  to ->  7
# From:  captcha/test_set/T/343.png  to ->  7
# From:  captcha/test_set/T/1823.png  to ->  X
# From:  captcha/test_set/T/384.png  to ->  7
# From:  captcha/test_set/T/1604.png  to ->  7
# From:  captcha/test_set/T/623.png  to ->  7
# From:  captcha/test_set/T/804.png  to ->  7
# From:  captcha/test_set/T/757.png  to ->  Z
# From:  captcha/test_set/T/970.png  to ->  X
# From:  captcha/test_set/T/583.png  to ->  X
# From:  captcha/test_set/T/971.png  to ->  R
# From:  captcha/test_set/T/805.png  to ->  7
# From:  captcha/test_set/T/86.png  to ->  7
# From:  captcha/test_set/T/422.png  to ->  7
# From:  captcha/test_set/T/387.png  to ->  7
# From:  captcha/test_set/T/608.png  to ->  7
# From:  captcha/test_set/T/1363.png  to ->  K
# From:  captcha/test_set/T/807.png  to ->  7
# From:  captcha/test_set/T/998.png  to ->  7
# From:  captcha/test_set/T/1217.png  to ->  7
# From:  captcha/test_set/T/1203.png  to ->  7
# From:  captcha/test_set/T/224.png  to ->  2
# From:  captcha/test_set/T/1799.png  to ->  7
# From:  captcha/test_set/T/225.png  to ->  7
# From:  captcha/test_set/T/1410.png  to ->  Z
# From:  captcha/test_set/T/1404.png  to ->  7
# From:  captcha/test_set/T/1389.png  to ->  V
# From:  captcha/test_set/T/609.png  to ->  Z
# From:  captcha/test_set/F/360.png  to ->  P
# From:  captcha/test_set/F/1623.png  to ->  E
# From:  captcha/test_set/F/1347.png  to ->  E
# From:  captcha/test_set/F/1541.png  to ->  E
# From:  captcha/test_set/F/228.png  to ->  E
# From:  captcha/test_set/F/1025.png  to ->  K
# From:  captcha/test_set/F/573.png  to ->  E
# From:  captcha/test_set/F/201.png  to ->  P
# From:  captcha/test_set/F/1540.png  to ->  K
# From:  captcha/test_set/F/942.png  to ->  P
# From:  captcha/test_set/F/1408.png  to ->  E
# From:  captcha/test_set/F/177.png  to ->  4
# From:  captcha/test_set/F/809.png  to ->  E
# From:  captcha/test_set/F/174.png  to ->  4
# From:  captcha/test_set/F/1621.png  to ->  E
# From:  captcha/test_set/F/428.png  to ->  E
# From:  captcha/test_set/F/1631.png  to ->  K
# From:  captcha/test_set/F/776.png  to ->  E
# From:  captcha/test_set/F/945.png  to ->  6
# From:  captcha/test_set/F/212.png  to ->  K
# From:  captcha/test_set/F/560.png  to ->  E
# From:  captcha/test_set/F/1023.png  to ->  A
# From:  captcha/test_set/F/1208.png  to ->  6
# From:  captcha/test_set/F/1546.png  to ->  A
# From:  captcha/test_set/F/167.png  to ->  R
# From:  captcha/test_set/F/1395.png  to ->  4
# From:  captcha/test_set/F/1430.png  to ->  P
# From:  captcha/test_set/F/775.png  to ->  4
# From:  captcha/test_set/F/1550.png  to ->  P
# From:  captcha/test_set/F/589.png  to ->  E
# From:  captcha/test_set/F/1551.png  to ->  4
# From:  captcha/test_set/F/172.png  to ->  4
# From:  captcha/test_set/F/1141.png  to ->  E
# From:  captcha/test_set/F/471.png  to ->  P
# From:  captcha/test_set/F/1495.png  to ->  R
# From:  captcha/test_set/F/667.png  to ->  4
# From:  captcha/test_set/F/1536.png  to ->  4
# From:  captcha/test_set/F/1244.png  to ->  R
# From:  captcha/test_set/F/263.png  to ->  E
# From:  captcha/test_set/F/505.png  to ->  E
# From:  captcha/test_set/F/1053.png  to ->  E
# From:  captcha/test_set/F/1090.png  to ->  E
# From:  captcha/test_set/F/921.png  to ->  4
# From:  captcha/test_set/F/1443.png  to ->  4
# From:  captcha/test_set/F/841.png  to ->  E
# From:  captcha/test_set/F/855.png  to ->  R
# From:  captcha/test_set/F/1655.png  to ->  E
# From:  captcha/test_set/F/499.png  to ->  P
# From:  captcha/test_set/F/1131.png  to ->  E
# From:  captcha/test_set/F/1482.png  to ->  P
# From:  captcha/test_set/F/843.png  to ->  4
# From:  captcha/test_set/F/1455.png  to ->  E
# From:  captcha/test_set/F/275.png  to ->  R
# From:  captcha/test_set/F/513.png  to ->  E
# From:  captcha/test_set/F/1468.png  to ->  P
# From:  captcha/test_set/F/498.png  to ->  R
# From:  captcha/test_set/F/477.png  to ->  4
# From:  captcha/test_set/F/729.png  to ->  4
# From:  captcha/test_set/F/1242.png  to ->  4
# From:  captcha/test_set/F/1083.png  to ->  E
# From:  captcha/test_set/F/1519.png  to ->  E
# From:  captcha/test_set/F/1280.png  to ->  E
# From:  captcha/test_set/F/1451.png  to ->  E
# From:  captcha/test_set/F/1684.png  to ->  E
# From:  captcha/test_set/F/702.png  to ->  E
# From:  captcha/test_set/F/1080.png  to ->  R
# From:  captcha/test_set/F/1719.png  to ->  E
# From:  captcha/test_set/F/1095.png  to ->  E
# From:  captcha/test_set/F/1297.png  to ->  E
# From:  captcha/test_set/F/703.png  to ->  4
# From:  captcha/test_set/F/887.png  to ->  E
# From:  captcha/test_set/F/1678.png  to ->  4
# From:  captcha/test_set/F/307.png  to ->  A
# From:  captcha/test_set/F/1488.png  to ->  H
# From:  captcha/test_set/F/646.png  to ->  E
# From:  captcha/test_set/F/691.png  to ->  R
# From:  captcha/test_set/F/1517.png  to ->  4
# From:  captcha/test_set/F/1304.png  to ->  4
# From:  captcha/test_set/F/647.png  to ->  4
# From:  captcha/test_set/F/1110.png  to ->  R
# From:  captcha/test_set/F/1662.png  to ->  P
# From:  captcha/test_set/F/1528.png  to ->  E
# From:  captcha/test_set/F/296.png  to ->  E
# From:  captcha/test_set/F/1267.png  to ->  4
# From:  captcha/test_set/F/917.png  to ->  P
# From:  captcha/test_set/F/1307.png  to ->  R
# From:  captcha/test_set/F/1101.png  to ->  R
# From:  captcha/test_set/F/126.png  to ->  E
# From:  captcha/test_set/F/1303.png  to ->  E
# From:  captcha/test_set/F/1288.png  to ->  E
# From:  captcha/test_set/F/1539.png  to ->  E
# From:  captcha/test_set/F/1706.png  to ->  E
# From:  captcha/test_set/F/523.png  to ->  6
# From:  captcha/test_set/F/906.png  to ->  E
# From:  captcha/test_set/F/1538.png  to ->  K
# From:  captcha/test_set/F/721.png  to ->  4
# From:  captcha/test_set/F/1316.png  to ->  R
# From:  captcha/test_set/F/1699.png  to ->  4
# From:  captcha/test_set/F/119.png  to ->  A
# From:  captcha/test_set/F/509.png  to ->  6
# From:  captcha/test_set/F/534.png  to ->  R
# From:  captcha/test_set/F/911.png  to ->  4
# From:  captcha/test_set/F/440.png  to ->  A
# From:  captcha/test_set/F/355.png  to ->  E
# From:  captcha/test_set/F/1158.png  to ->  K
# From:  captcha/test_set/F/1164.png  to ->  E
# From:  captcha/test_set/F/1602.png  to ->  E
# From:  captcha/test_set/F/779.png  to ->  E
# From:  captcha/test_set/F/1548.png  to ->  E
# From:  captcha/test_set/F/962.png  to ->  4
# From:  captcha/test_set/F/1010.png  to ->  4
# From:  captcha/test_set/F/1011.png  to ->  E
# From:  captcha/test_set/F/963.png  to ->  P
# From:  captcha/test_set/F/426.png  to ->  4
# From:  captcha/test_set/F/342.png  to ->  4
# From:  captcha/test_set/F/82.png  to ->  E
# From:  captcha/test_set/F/1588.png  to ->  6
# From:  captcha/test_set/F/746.png  to ->  R
# From:  captcha/test_set/F/1012.png  to ->  E
# From:  captcha/test_set/F/1210.png  to ->  4
# From:  captcha/test_set/F/1576.png  to ->  4
# From:  captcha/test_set/F/182.png  to ->  E
# From:  captcha/test_set/F/1370.png  to ->  R
# From:  captcha/test_set/F/1614.png  to ->  E
# From:  captcha/test_set/F/1610.png  to ->  9
# From:  captcha/test_set/F/179.png  to ->  4
# From:  captcha/test_set/F/1412.png  to ->  P
# From:  captcha/test_set/F/804.png  to ->  P
# From:  captcha/test_set/F/757.png  to ->  7
# From:  captcha/test_set/F/226.png  to ->  4
# From:  captcha/test_set/F/193.png  to ->  P
# From:  captcha/test_set/F/1163.png  to ->  E
# From:  captcha/test_set/F/391.png  to ->  E
# From:  captcha/test_set/F/556.png  to ->  E
# From:  captcha/test_set/F/1001.png  to ->  E
# From:  captcha/test_set/F/595.png  to ->  E
# From:  captcha/test_set/F/755.png  to ->  E
# From:  captcha/test_set/F/1438.png  to ->  P
# From:  captcha/test_set/F/1404.png  to ->  4
# From:  captcha/test_set/F/91.png  to ->  A
# From:  captcha/test_set/F/153.png  to ->  9
# From:  captcha/test_set/H/412.png  to ->  K
# From:  captcha/test_set/H/1192.png  to ->  L
# From:  captcha/test_set/H/604.png  to ->  P
# From:  captcha/test_set/H/823.png  to ->  K
# From:  captcha/test_set/H/1569.png  to ->  4
# From:  captcha/test_set/H/214.png  to ->  P
# From:  captcha/test_set/H/1018.png  to ->  F
# From:  captcha/test_set/H/956.png  to ->  R
# From:  captcha/test_set/H/1608.png  to ->  E
# From:  captcha/test_set/H/1634.png  to ->  4
# From:  captcha/test_set/H/60.png  to ->  R
# From:  captcha/test_set/H/1581.png  to ->  A
# From:  captcha/test_set/H/798.png  to ->  4
# From:  captcha/test_set/H/1230.png  to ->  A
# From:  captcha/test_set/H/1740.png  to ->  9
# From:  captcha/test_set/H/564.png  to ->  A
# From:  captcha/test_set/H/558.png  to ->  P
# From:  captcha/test_set/H/1225.png  to ->  A
# From:  captcha/test_set/H/799.png  to ->  N
# From:  captcha/test_set/H/1594.png  to ->  R
# From:  captcha/test_set/H/996.png  to ->  4
# From:  captcha/test_set/H/75.png  to ->  2
# From:  captcha/test_set/H/61.png  to ->  R
# From:  captcha/test_set/H/1143.png  to ->  P
# From:  captcha/test_set/H/71.png  to ->  K
# From:  captcha/test_set/H/1221.png  to ->  R
# From:  captcha/test_set/H/548.png  to ->  N
# From:  captcha/test_set/H/1745.png  to ->  F
# From:  captcha/test_set/H/1036.png  to ->  N
# From:  captcha/test_set/H/944.png  to ->  8
# From:  captcha/test_set/H/1591.png  to ->  N
# From:  captcha/test_set/H/777.png  to ->  R
# From:  captcha/test_set/H/617.png  to ->  F
# From:  captcha/test_set/H/1381.png  to ->  L
# From:  captcha/test_set/H/72.png  to ->  U
# From:  captcha/test_set/H/1418.png  to ->  N
# From:  captcha/test_set/H/1593.png  to ->  R
# From:  captcha/test_set/H/749.png  to ->  U
# From:  captcha/test_set/H/774.png  to ->  K
# From:  captcha/test_set/H/73.png  to ->  K
# From:  captcha/test_set/H/1419.png  to ->  R
# From:  captcha/test_set/H/9.png  to ->  K
# From:  captcha/test_set/H/1425.png  to ->  U
# From:  captcha/test_set/H/600.png  to ->  L
# From:  captcha/test_set/H/1633.png  to ->  Q
# From:  captcha/test_set/H/402.png  to ->  K
# From:  captcha/test_set/H/1640.png  to ->  2
# From:  captcha/test_set/H/883.png  to ->  K
# From:  captcha/test_set/H/667.png  to ->  R
# From:  captcha/test_set/H/698.png  to ->  P
# From:  captcha/test_set/H/713.png  to ->  K
# From:  captcha/test_set/H/1536.png  to ->  L
# From:  captcha/test_set/H/908.png  to ->  K
# From:  captcha/test_set/H/505.png  to ->  R
# From:  captcha/test_set/H/1734.png  to ->  P
# From:  captcha/test_set/H/1047.png  to ->  R
# From:  captcha/test_set/H/909.png  to ->  R
# From:  captcha/test_set/H/699.png  to ->  L
# From:  captcha/test_set/H/855.png  to ->  U
# From:  captcha/test_set/H/882.png  to ->  U
# From:  captcha/test_set/H/1696.png  to ->  U
# From:  captcha/test_set/H/470.png  to ->  K
# From:  captcha/test_set/H/670.png  to ->  L
# From:  captcha/test_set/H/1333.png  to ->  R
# From:  captcha/test_set/H/1441.png  to ->  K
# From:  captcha/test_set/H/512.png  to ->  P
# From:  captcha/test_set/H/1737.png  to ->  P
# From:  captcha/test_set/H/1044.png  to ->  R
# From:  captcha/test_set/H/1252.png  to ->  P
# From:  captcha/test_set/H/936.png  to ->  R
# From:  captcha/test_set/H/1285.png  to ->  P
# From:  captcha/test_set/H/1326.png  to ->  N
# From:  captcha/test_set/H/856.png  to ->  P
# From:  captcha/test_set/H/671.png  to ->  N
# From:  captcha/test_set/H/665.png  to ->  U
# From:  captcha/test_set/H/305.png  to ->  P
# From:  captcha/test_set/H/311.png  to ->  P
# From:  captcha/test_set/H/1336.png  to ->  F
# From:  captcha/test_set/H/1281.png  to ->  N
# From:  captcha/test_set/H/517.png  to ->  N
# From:  captcha/test_set/H/1069.png  to ->  P
# From:  captcha/test_set/H/700.png  to ->  4
# From:  captcha/test_set/H/853.png  to ->  U
# From:  captcha/test_set/H/1445.png  to ->  N
# From:  captcha/test_set/H/884.png  to ->  D
# From:  captcha/test_set/H/1135.png  to ->  Q
# From:  captcha/test_set/H/662.png  to ->  U
# From:  captcha/test_set/H/845.png  to ->  A
# From:  captcha/test_set/H/514.png  to ->  R
# From:  captcha/test_set/H/1043.png  to ->  P
# From:  captcha/test_set/H/529.png  to ->  P
# From:  captcha/test_set/H/307.png  to ->  P
# From:  captcha/test_set/H/450.png  to ->  4
# From:  captcha/test_set/H/1729.png  to ->  R
# From:  captcha/test_set/H/281.png  to ->  L
# From:  captcha/test_set/H/1701.png  to ->  R
# From:  captcha/test_set/H/519.png  to ->  R
# From:  captcha/test_set/H/727.png  to ->  R
# From:  captcha/test_set/H/684.png  to ->  P
# From:  captcha/test_set/H/1462.png  to ->  P
# From:  captcha/test_set/H/121.png  to ->  R
# From:  captcha/test_set/H/135.png  to ->  L
# From:  captcha/test_set/H/323.png  to ->  K
# From:  captcha/test_set/H/1138.png  to ->  A
# From:  captcha/test_set/H/686.png  to ->  N
# From:  captcha/test_set/H/731.png  to ->  R
# From:  captcha/test_set/H/1528.png  to ->  R
# From:  captcha/test_set/H/269.png  to ->  P
# From:  captcha/test_set/H/724.png  to ->  6
# From:  captcha/test_set/H/687.png  to ->  K
# From:  captcha/test_set/H/678.png  to ->  P
# From:  captcha/test_set/H/1101.png  to ->  N
# From:  captcha/test_set/H/867.png  to ->  F
# From:  captcha/test_set/H/1049.png  to ->  F
# From:  captcha/test_set/H/1048.png  to ->  K
# From:  captcha/test_set/H/286.png  to ->  4
# From:  captcha/test_set/H/279.png  to ->  N
# From:  captcha/test_set/H/1276.png  to ->  R
# From:  captcha/test_set/H/1289.png  to ->  N
# From:  captcha/test_set/H/1302.png  to ->  U
# From:  captcha/test_set/H/1658.png  to ->  F
# From:  captcha/test_set/H/534.png  to ->  A
# From:  captcha/test_set/H/520.png  to ->  K
# From:  captcha/test_set/H/911.png  to ->  V
# From:  captcha/test_set/H/681.png  to ->  X
# From:  captcha/test_set/H/130.png  to ->  K
# From:  captcha/test_set/H/656.png  to ->  P
# From:  captcha/test_set/H/1665.png  to ->  R
# From:  captcha/test_set/H/1602.png  to ->  N
# From:  captcha/test_set/H/157.png  to ->  F
# From:  captcha/test_set/H/4.png  to ->  R
# From:  captcha/test_set/H/194.png  to ->  R
# From:  captcha/test_set/H/221.png  to ->  R
# From:  captcha/test_set/H/1763.png  to ->  L
# From:  captcha/test_set/H/234.png  to ->  2
# From:  captcha/test_set/H/552.png  to ->  K
# From:  captcha/test_set/H/963.png  to ->  8
# From:  captcha/test_set/H/181.png  to ->  R
# From:  captcha/test_set/H/817.png  to ->  F
# From:  captcha/test_set/H/142.png  to ->  L
# From:  captcha/test_set/H/424.png  to ->  N
# From:  captcha/test_set/H/381.png  to ->  K
# From:  captcha/test_set/H/632.png  to ->  N
# From:  captcha/test_set/H/1359.png  to ->  K
# From:  captcha/test_set/H/1417.png  to ->  P
# From:  captcha/test_set/H/197.png  to ->  N
# From:  captcha/test_set/H/746.png  to ->  U
# From:  captcha/test_set/H/550.png  to ->  K
# From:  captcha/test_set/H/544.png  to ->  R
# From:  captcha/test_set/H/196.png  to ->  E
# From:  captcha/test_set/H/1358.png  to ->  R
# From:  captcha/test_set/H/380.png  to ->  V
# From:  captcha/test_set/H/431.png  to ->  N
# From:  captcha/test_set/H/435.png  to ->  R
# From:  captcha/test_set/H/1176.png  to ->  P
# From:  captcha/test_set/H/1572.png  to ->  F
# From:  captcha/test_set/H/970.png  to ->  Y
# From:  captcha/test_set/H/233.png  to ->  P
# From:  captcha/test_set/H/596.png  to ->  R
# From:  captcha/test_set/H/232.png  to ->  N
# From:  captcha/test_set/H/1201.png  to ->  P
# From:  captcha/test_set/H/742.png  to ->  P
# From:  captcha/test_set/H/408.png  to ->  P
# From:  captcha/test_set/H/1175.png  to ->  N
# From:  captcha/test_set/H/1405.png  to ->  K
# From:  captcha/test_set/H/998.png  to ->  N
# From:  captcha/test_set/H/1571.png  to ->  E
# From:  captcha/test_set/H/230.png  to ->  R
# From:  captcha/test_set/H/1028.png  to ->  X
# From:  captcha/test_set/H/769.png  to ->  U
# From:  captcha/test_set/H/1148.png  to ->  6
# From:  captcha/test_set/H/392.png  to ->  J
# From:  captcha/test_set/H/345.png  to ->  X
# From:  captcha/test_set/J/980.png  to ->  2
# From:  captcha/test_set/J/228.png  to ->  D
# From:  captcha/test_set/J/566.png  to ->  3
# From:  captcha/test_set/J/599.png  to ->  Q
# From:  captcha/test_set/J/567.png  to ->  3
# From:  captcha/test_set/J/229.png  to ->  3
# From:  captcha/test_set/J/765.png  to ->  D
# From:  captcha/test_set/J/375.png  to ->  3
# From:  captcha/test_set/J/349.png  to ->  P
# From:  captcha/test_set/J/1185.png  to ->  Q
# From:  captcha/test_set/J/968.png  to ->  3
# From:  captcha/test_set/J/1033.png  to ->  3
# From:  captcha/test_set/J/399.png  to ->  D
# From:  captcha/test_set/J/776.png  to ->  3
# From:  captcha/test_set/J/548.png  to ->  D
# From:  captcha/test_set/J/1022.png  to ->  6
# From:  captcha/test_set/J/561.png  to ->  D
# From:  captcha/test_set/J/415.png  to ->  3
# From:  captcha/test_set/J/1008.png  to ->  3
# From:  captcha/test_set/J/204.png  to ->  D
# From:  captcha/test_set/J/562.png  to ->  D
# From:  captcha/test_set/J/1237.png  to ->  3
# From:  captcha/test_set/J/303.png  to ->  Q
# From:  captcha/test_set/J/1293.png  to ->  Q
# From:  captcha/test_set/J/908.png  to ->  3
# From:  captcha/test_set/J/1084.png  to ->  D
# From:  captcha/test_set/J/276.png  to ->  U
# From:  captcha/test_set/J/1090.png  to ->  3
# From:  captcha/test_set/J/909.png  to ->  3
# From:  captcha/test_set/J/1279.png  to ->  N
# From:  captcha/test_set/J/869.png  to ->  3
# From:  captcha/test_set/J/672.png  to ->  U
# From:  captcha/test_set/J/114.png  to ->  3
# From:  captcha/test_set/J/1127.png  to ->  Q
# From:  captcha/test_set/J/328.png  to ->  9
# From:  captcha/test_set/J/1247.png  to ->  X
# From:  captcha/test_set/J/881.png  to ->  3
# From:  captcha/test_set/J/659.png  to ->  D
# From:  captcha/test_set/J/271.png  to ->  Q
# From:  captcha/test_set/J/1055.png  to ->  3
# From:  captcha/test_set/J/516.png  to ->  3
# From:  captcha/test_set/J/674.png  to ->  3
# From:  captcha/test_set/J/489.png  to ->  6
# From:  captcha/test_set/J/892.png  to ->  9
# From:  captcha/test_set/J/886.png  to ->  3
# From:  captcha/test_set/J/716.png  to ->  3
# From:  captcha/test_set/J/925.png  to ->  D
# From:  captcha/test_set/J/298.png  to ->  9
# From:  captcha/test_set/J/273.png  to ->  D
# From:  captcha/test_set/J/1268.png  to ->  U
# From:  captcha/test_set/J/717.png  to ->  3
# From:  captcha/test_set/J/844.png  to ->  2
# From:  captcha/test_set/J/685.png  to ->  A
# From:  captcha/test_set/J/727.png  to ->  3
# From:  captcha/test_set/J/490.png  to ->  3
# From:  captcha/test_set/J/527.png  to ->  G
# From:  captcha/test_set/J/268.png  to ->  D
# From:  captcha/test_set/J/1307.png  to ->  6
# From:  captcha/test_set/J/687.png  to ->  9
# From:  captcha/test_set/J/136.png  to ->  3
# From:  captcha/test_set/J/678.png  to ->  3
# From:  captcha/test_set/J/318.png  to ->  Q
# From:  captcha/test_set/J/640.png  to ->  D
# From:  captcha/test_set/J/244.png  to ->  3
# From:  captcha/test_set/J/735.png  to ->  9
# From:  captcha/test_set/J/669.png  to ->  3
# From:  captcha/test_set/J/443.png  to ->  U
# From:  captcha/test_set/J/455.png  to ->  3
# From:  captcha/test_set/J/496.png  to ->  Q
# From:  captcha/test_set/J/482.png  to ->  N
# From:  captcha/test_set/J/1260.png  to ->  D
# From:  captcha/test_set/J/1062.png  to ->  U
# From:  captcha/test_set/J/722.png  to ->  U
# From:  captcha/test_set/J/355.png  to ->  3
# From:  captcha/test_set/J/1158.png  to ->  3
# From:  captcha/test_set/J/209.png  to ->  3
# From:  captcha/test_set/J/618.png  to ->  D
# From:  captcha/test_set/J/94.png  to ->  3
# From:  captcha/test_set/J/340.png  to ->  9
# From:  captcha/test_set/J/550.png  to ->  9
# From:  captcha/test_set/J/579.png  to ->  D
# From:  captcha/test_set/J/1210.png  to ->  9
# From:  captcha/test_set/J/1204.png  to ->  Q
# From:  captcha/test_set/J/633.png  to ->  N
# From:  captcha/test_set/J/1189.png  to ->  3
# From:  captcha/test_set/J/838.png  to ->  Q
# From:  captcha/test_set/J/226.png  to ->  2
# From:  captcha/test_set/J/971.png  to ->  9
# From:  captcha/test_set/J/781.png  to ->  3
# From:  captcha/test_set/J/805.png  to ->  3
# From:  captcha/test_set/J/193.png  to ->  G
# From:  captcha/test_set/J/622.png  to ->  D
# From:  captcha/test_set/J/408.png  to ->  3
# From:  captcha/test_set/J/350.png  to ->  9
# From:  captcha/test_set/J/90.png  to ->  3
# From:  captcha/test_set/J/754.png  to ->  3
# From:  captcha/test_set/J/230.png  to ->  3
# From:  captcha/test_set/J/557.png  to ->  3
# From:  captcha/test_set/J/966.png  to ->  3
# From:  captcha/test_set/J/1174.png  to ->  9
# From:  captcha/test_set/C/348.png  to ->  V
# From:  captcha/test_set/C/1810.png  to ->  Q
# From:  captcha/test_set/C/1838.png  to ->  Q
# From:  captcha/test_set/C/360.png  to ->  D
# From:  captcha/test_set/C/1179.png  to ->  Q
# ...
# From:  captcha/test_set/V/1090.png  to ->  Y
# From:  captcha/test_set/V/1523.png  to ->  7
# From:  captcha/test_set/V/1331.png  to ->  4
# From:  captcha/test_set/V/1325.png  to ->  L
# From:  captcha/test_set/V/114.png  to ->  7
# From:  captcha/test_set/V/316.png  to ->  7
# From:  captcha/test_set/V/300.png  to ->  7
# From:  captcha/test_set/V/466.png  to ->  L
# From:  captcha/test_set/V/1119.png  to ->  Y
# From:  captcha/test_set/V/1125.png  to ->  Y
# From:  captcha/test_set/V/102.png  to ->  7
# From:  captcha/test_set/V/1482.png  to ->  L
# From:  captcha/test_set/V/1441.png  to ->  Y
# From:  captcha/test_set/V/248.png  to ->  7
# From:  captcha/test_set/V/1050.png  to ->  7
# From:  captcha/test_set/V/1044.png  to ->  Y
# From:  captcha/test_set/V/1905.png  to ->  7
# From:  captcha/test_set/V/1520.png  to ->  7
# From:  captcha/test_set/V/1508.png  to ->  Y
# From:  captcha/test_set/V/739.png  to ->  N
# From:  captcha/test_set/V/659.png  to ->  N
# From:  captcha/test_set/V/1130.png  to ->  X
# From:  captcha/test_set/V/329.png  to ->  Y
# From:  captcha/test_set/V/1652.png  to ->  7
# From:  captcha/test_set/V/675.png  to ->  L
# From:  captcha/test_set/V/715.png  to ->  7
# From:  captcha/test_set/V/1929.png  to ->  F
# From:  captcha/test_set/V/1732.png  to ->  L
# From:  captcha/test_set/V/1068.png  to ->  2
# From:  captcha/test_set/V/1055.png  to ->  X
# From:  captcha/test_set/V/264.png  to ->  7
# From:  captcha/test_set/V/1096.png  to ->  Y
# From:  captcha/test_set/V/1519.png  to ->  X
# From:  captcha/test_set/V/728.png  to ->  Y
# From:  captcha/test_set/V/847.png  to ->  Y
# From:  captcha/test_set/V/1121.png  to ->  X
# From:  captcha/test_set/V/462.png  to ->  X
# From:  captcha/test_set/V/1692.png  to ->  Y
# From:  captcha/test_set/V/1123.png  to ->  L
# From:  captcha/test_set/V/1651.png  to ->  7
# From:  captcha/test_set/V/1137.png  to ->  7
# From:  captcha/test_set/V/1679.png  to ->  7
# From:  captcha/test_set/V/1533.png  to ->  7
# From:  captcha/test_set/V/1718.png  to ->  X
# From:  captcha/test_set/V/1724.png  to ->  7
# From:  captcha/test_set/V/1042.png  to ->  X
# From:  captcha/test_set/V/1903.png  to ->  F
# From:  captcha/test_set/V/1526.png  to ->  L
# From:  captcha/test_set/V/717.png  to ->  7
# From:  captcha/test_set/V/105.png  to ->  Z
# From:  captcha/test_set/V/1136.png  to ->  7
# From:  captcha/test_set/V/1477.png  to ->  7
# From:  captcha/test_set/V/1259.png  to ->  X
# From:  captcha/test_set/V/243.png  to ->  N
# From:  captcha/test_set/V/1927.png  to ->  T
# From:  captcha/test_set/V/928.png  to ->  Y
# From:  captcha/test_set/V/848.png  to ->  T
# From:  captcha/test_set/V/653.png  to ->  2
# From:  captcha/test_set/V/1674.png  to ->  7
# From:  captcha/test_set/V/1110.png  to ->  F
# From:  captcha/test_set/V/1104.png  to ->  7
# From:  captcha/test_set/V/645.png  to ->  P
# From:  captcha/test_set/V/862.png  to ->  4
# From:  captcha/test_set/V/1058.png  to ->  7
# From:  captcha/test_set/V/1716.png  to ->  Y
# From:  captcha/test_set/V/268.png  to ->  N
# From:  captcha/test_set/V/1924.png  to ->  7
# From:  captcha/test_set/V/1267.png  to ->  T
# From:  captcha/test_set/V/1475.png  to ->  Y
# From:  captcha/test_set/V/1449.png  to ->  Y
# From:  captcha/test_set/V/678.png  to ->  L
# From:  captcha/test_set/V/1663.png  to ->  7
# From:  captcha/test_set/V/1677.png  to ->  4
# From:  captcha/test_set/V/320.png  to ->  7
# From:  captcha/test_set/V/1850.png  to ->  7
# From:  captcha/test_set/V/1868.png  to ->  R
# From:  captcha/test_set/V/1854.png  to ->  T
# From:  captcha/test_set/V/1840.png  to ->  Y
# From:  captcha/test_set/V/126.png  to ->  Y
# From:  captcha/test_set/V/668.png  to ->  L
# From:  captcha/test_set/V/1465.png  to ->  Y
# From:  captcha/test_set/V/1707.png  to ->  X
# From:  captcha/test_set/V/286.png  to ->  L
# From:  captcha/test_set/V/537.png  to ->  L
# From:  captcha/test_set/V/251.png  to ->  7
# From:  captcha/test_set/V/912.png  to ->  L
# From:  captcha/test_set/V/1289.png  to ->  Y
# From:  captcha/test_set/V/709.png  to ->  Y
# From:  captcha/test_set/V/1470.png  to ->  Y
# From:  captcha/test_set/V/1882.png  to ->  Z
# From:  captcha/test_set/V/125.png  to ->  7
# From:  captcha/test_set/V/737.png  to ->  7
# From:  captcha/test_set/V/509.png  to ->  X
# From:  captcha/test_set/V/290.png  to ->  H
# From:  captcha/test_set/V/1077.png  to ->  7
# From:  captcha/test_set/V/1249.png  to ->  7
# From:  captcha/test_set/V/1507.png  to ->  Q
# From:  captcha/test_set/V/865.png  to ->  7
# From:  captcha/test_set/V/1315.png  to ->  X
# From:  captcha/test_set/V/1301.png  to ->  T
# From:  captcha/test_set/V/130.png  to ->  X
# From:  captcha/test_set/V/1881.png  to ->  Y
# From:  captcha/test_set/V/1671.png  to ->  7
# From:  captcha/test_set/V/433.png  to ->  L
# From:  captcha/test_set/V/1158.png  to ->  Z
# From:  captcha/test_set/V/625.png  to ->  L
# From:  captcha/test_set/V/976.png  to ->  7
# From:  captcha/test_set/V/553.png  to ->  L
# From:  captcha/test_set/V/1038.png  to ->  Y
# From:  captcha/test_set/V/591.png  to ->  Y
# From:  captcha/test_set/V/750.png  to ->  X
# From:  captcha/test_set/V/817.png  to ->  7
# From:  captcha/test_set/V/383.png  to ->  L
# From:  captcha/test_set/V/1171.png  to ->  Z
# From:  captcha/test_set/V/1198.png  to ->  X
# From:  captcha/test_set/V/395.png  to ->  P
# From:  captcha/test_set/V/632.png  to ->  Y
# From:  captcha/test_set/V/154.png  to ->  Z
# From:  captcha/test_set/V/975.png  to ->  7
# From:  captcha/test_set/V/223.png  to ->  Y
# From:  captcha/test_set/V/579.png  to ->  Z
# From:  captcha/test_set/V/1562.png  to ->  7
# From:  captcha/test_set/V/1402.png  to ->  Y
# From:  captcha/test_set/V/800.png  to ->  Y
# From:  captcha/test_set/V/97.png  to ->  7
# From:  captcha/test_set/V/425.png  to ->  Y
# From:  captcha/test_set/V/1199.png  to ->  L
# From:  captcha/test_set/V/1610.png  to ->  T
# From:  captcha/test_set/V/838.png  to ->  T
# From:  captcha/test_set/V/743.png  to ->  L
# From:  captcha/test_set/V/1566.png  to ->  L
# From:  captcha/test_set/V/958.png  to ->  7
# From:  captcha/test_set/V/970.png  to ->  P
# From:  captcha/test_set/V/227.png  to ->  Y
# From:  captcha/test_set/V/569.png  to ->  L
# From:  captcha/test_set/V/583.png  to ->  P
# From:  captcha/test_set/V/805.png  to ->  N
# From:  captcha/test_set/V/1639.png  to ->  L
# From:  captcha/test_set/V/385.png  to ->  7
# From:  captcha/test_set/V/352.png  to ->  Y
# From:  captcha/test_set/V/422.png  to ->  Q
# From:  captcha/test_set/V/344.png  to ->  Y
# From:  captcha/test_set/V/1834.png  to ->  Y
# From:  captcha/test_set/V/387.png  to ->  Z
# From:  captcha/test_set/V/152.png  to ->  2
# From:  captcha/test_set/V/1217.png  to ->  7
# From:  captcha/test_set/V/224.png  to ->  7
# From:  captcha/test_set/V/1773.png  to ->  Y
# From:  captcha/test_set/V/581.png  to ->  X
# From:  captcha/test_set/V/1767.png  to ->  7
# From:  captcha/test_set/V/594.png  to ->  H
# From:  captcha/test_set/V/1772.png  to ->  2
# From:  captcha/test_set/V/1570.png  to ->  K
# From:  captcha/test_set/V/1438.png  to ->  X
# From:  captcha/test_set/V/184.png  to ->  7
# From:  captcha/test_set/V/1362.png  to ->  7
# From:  captcha/test_set/V/91.png  to ->  Z
# From:  captcha/test_set/V/386.png  to ->  N
# From:  captcha/test_set/V/1835.png  to ->  Y
# From:  captcha/test_set/Q/162.png  to ->  D
# From:  captcha/test_set/Q/837.png  to ->  D
# From:  captcha/test_set/Q/228.png  to ->  D
# From:  captcha/test_set/Q/572.png  to ->  D
# From:  captcha/test_set/Q/567.png  to ->  U
# From:  captcha/test_set/Q/201.png  to ->  3
# From:  captcha/test_set/Q/956.png  to ->  2
# From:  captcha/test_set/Q/771.png  to ->  A
# From:  captcha/test_set/Q/76.png  to ->  4
# From:  captcha/test_set/Q/836.png  to ->  D
# From:  captcha/test_set/Q/388.png  to ->  D
# From:  captcha/test_set/Q/74.png  to ->  D
# From:  captcha/test_set/Q/48.png  to ->  6
# From:  captcha/test_set/Q/773.png  to ->  6
# From:  captcha/test_set/Q/954.png  to ->  D
# From:  captcha/test_set/Q/798.png  to ->  U
# From:  captcha/test_set/Q/955.png  to ->  D
# From:  captcha/test_set/Q/766.png  to ->  D
# From:  captcha/test_set/Q/809.png  to ->  3
# From:  captcha/test_set/Q/612.png  to ->  J
# From:  captcha/test_set/Q/376.png  to ->  H
# From:  captcha/test_set/Q/366.png  to ->  U
# From:  captcha/test_set/Q/414.png  to ->  J
# From:  captcha/test_set/Q/428.png  to ->  D
# From:  captcha/test_set/Q/616.png  to ->  3
# From:  captcha/test_set/Q/158.png  to ->  6
# From:  captcha/test_set/Q/59.png  to ->  H
# From:  captcha/test_set/Q/560.png  to ->  G
# From:  captcha/test_set/Q/548.png  to ->  C
# From:  captcha/test_set/Q/415.png  to ->  D
# From:  captcha/test_set/Q/401.png  to ->  A
# From:  captcha/test_set/Q/403.png  to ->  G
# From:  captcha/test_set/Q/173.png  to ->  J
# From:  captcha/test_set/Q/204.png  to ->  6
# From:  captcha/test_set/Q/67.png  to ->  C
# From:  captcha/test_set/Q/98.png  to ->  G
# From:  captcha/test_set/Q/465.png  to ->  D
# From:  captcha/test_set/Q/883.png  to ->  J
# From:  captcha/test_set/Q/673.png  to ->  U
# From:  captcha/test_set/Q/868.png  to ->  A
# From:  captcha/test_set/Q/707.png  to ->  G
# From:  captcha/test_set/Q/934.png  to ->  U
# From:  captcha/test_set/Q/511.png  to ->  3
# From:  captcha/test_set/Q/277.png  to ->  D
# From:  captcha/test_set/Q/289.png  to ->  A
# From:  captcha/test_set/Q/262.png  to ->  J
# From:  captcha/test_set/Q/504.png  to ->  G
# From:  captcha/test_set/Q/921.png  to ->  G
# From:  captcha/test_set/Q/464.png  to ->  G
# From:  captcha/test_set/Q/470.png  to ->  C
# From:  captcha/test_set/Q/300.png  to ->  U
# From:  captcha/test_set/Q/499.png  to ->  J
# From:  captcha/test_set/Q/857.png  to ->  C
# From:  captcha/test_set/Q/937.png  to ->  D
# From:  captcha/test_set/Q/506.png  to ->  6
# From:  captcha/test_set/Q/103.png  to ->  G
# From:  captcha/test_set/Q/881.png  to ->  4
# From:  captcha/test_set/Q/315.png  to ->  3
# From:  captcha/test_set/Q/488.png  to ->  D
# From:  captcha/test_set/Q/661.png  to ->  9
# From:  captcha/test_set/Q/852.png  to ->  U
# From:  captcha/test_set/Q/729.png  to ->  A
# From:  captcha/test_set/Q/517.png  to ->  3
# From:  captcha/test_set/Q/264.png  to ->  C
# From:  captcha/test_set/Q/516.png  to ->  J
# From:  captcha/test_set/Q/270.png  to ->  A
# From:  captcha/test_set/Q/728.png  to ->  C
# From:  captcha/test_set/Q/700.png  to ->  G
# From:  captcha/test_set/Q/884.png  to ->  U
# From:  captcha/test_set/Q/489.png  to ->  3
# From:  captcha/test_set/Q/338.png  to ->  D
# From:  captcha/test_set/Q/110.png  to ->  3
# From:  captcha/test_set/Q/702.png  to ->  N
# From:  captcha/test_set/Q/925.png  to ->  G
# From:  captcha/test_set/Q/500.png  to ->  J
# From:  captcha/test_set/Q/529.png  to ->  J
# From:  captcha/test_set/Q/688.png  to ->  U
# From:  captcha/test_set/Q/887.png  to ->  D
# From:  captcha/test_set/Q/105.png  to ->  4
# From:  captcha/test_set/Q/444.png  to ->  J
# From:  captcha/test_set/Q/875.png  to ->  J
# From:  captcha/test_set/Q/35.png  to ->  C
# From:  captcha/test_set/Q/21.png  to ->  U
# From:  captcha/test_set/Q/726.png  to ->  C
# From:  captcha/test_set/Q/256.png  to ->  U
# From:  captcha/test_set/Q/733.png  to ->  A
# From:  captcha/test_set/Q/20.png  to ->  9
# From:  captcha/test_set/Q/874.png  to ->  J
# From:  captcha/test_set/Q/647.png  to ->  C
# From:  captcha/test_set/Q/135.png  to ->  N
# From:  captcha/test_set/Q/451.png  to ->  8
# From:  captcha/test_set/Q/679.png  to ->  U
# From:  captcha/test_set/Q/123.png  to ->  D
# From:  captcha/test_set/Q/22.png  to ->  D
# From:  captcha/test_set/Q/36.png  to ->  D
# From:  captcha/test_set/Q/533.png  to ->  D
# From:  captcha/test_set/Q/241.png  to ->  3
# From:  captcha/test_set/Q/240.png  to ->  N
# From:  captcha/test_set/Q/532.png  to ->  D
# From:  captcha/test_set/Q/268.png  to ->  D
# From:  captcha/test_set/Q/903.png  to ->  A
# From:  captcha/test_set/Q/877.png  to ->  D
# From:  captcha/test_set/Q/888.png  to ->  C
# From:  captcha/test_set/Q/650.png  to ->  U
# From:  captcha/test_set/Q/491.png  to ->  J
# From:  captcha/test_set/Q/481.png  to ->  6
# From:  captcha/test_set/Q/734.png  to ->  D
# From:  captcha/test_set/Q/720.png  to ->  3
# From:  captcha/test_set/Q/907.png  to ->  9
# From:  captcha/test_set/Q/906.png  to ->  G
# From:  captcha/test_set/Q/912.png  to ->  U
# From:  captcha/test_set/Q/709.png  to ->  9
# From:  captcha/test_set/Q/655.png  to ->  D
# From:  captcha/test_set/Q/899.png  to ->  2
# From:  captcha/test_set/Q/641.png  to ->  E
# From:  captcha/test_set/Q/904.png  to ->  D
# From:  captcha/test_set/Q/247.png  to ->  G
# From:  captcha/test_set/Q/520.png  to ->  9
# From:  captcha/test_set/Q/642.png  to ->  G
# From:  captcha/test_set/Q/124.png  to ->  7
# From:  captcha/test_set/Q/369.png  to ->  6
# From:  captcha/test_set/Q/433.png  to ->  G
# From:  captcha/test_set/Q/396.png  to ->  U
# From:  captcha/test_set/Q/816.png  to ->  U
# From:  captcha/test_set/Q/553.png  to ->  D
# From:  captcha/test_set/Q/591.png  to ->  6
# From:  captcha/test_set/Q/744.png  to ->  G
# From:  captcha/test_set/Q/181.png  to ->  D
# From:  captcha/test_set/Q/57.png  to ->  U
# From:  captcha/test_set/Q/624.png  to ->  D
# From:  captcha/test_set/Q/424.png  to ->  N
# From:  captcha/test_set/Q/381.png  to ->  D
# From:  captcha/test_set/Q/82.png  to ->  3
# From:  captcha/test_set/Q/168.png  to ->  U
# From:  captcha/test_set/Q/41.png  to ->  D
# From:  captcha/test_set/Q/69.png  to ->  D
# From:  captcha/test_set/Q/752.png  to ->  C
# From:  captcha/test_set/Q/746.png  to ->  D
# From:  captcha/test_set/Q/222.png  to ->  D
# From:  captcha/test_set/Q/237.png  to ->  U
# From:  captcha/test_set/Q/948.png  to ->  U
# From:  captcha/test_set/Q/814.png  to ->  J
# From:  captcha/test_set/Q/169.png  to ->  A
# From:  captcha/test_set/Q/637.png  to ->  D
# From:  captcha/test_set/Q/186.png  to ->  A
# From:  captcha/test_set/Q/192.png  to ->  3
# From:  captcha/test_set/Q/804.png  to ->  C
# From:  captcha/test_set/Q/743.png  to ->  J
# From:  captcha/test_set/Q/582.png  to ->  3
# From:  captcha/test_set/Q/742.png  to ->  D
# From:  captcha/test_set/Q/756.png  to ->  J
# From:  captcha/test_set/Q/622.png  to ->  D
# From:  captcha/test_set/Q/385.png  to ->  D
# From:  captcha/test_set/Q/408.png  to ->  C
# From:  captcha/test_set/Q/352.png  to ->  D
# From:  captcha/test_set/Q/608.png  to ->  2
# From:  captcha/test_set/Q/90.png  to ->  D
# From:  captcha/test_set/Q/191.png  to ->  C
# From:  captcha/test_set/Q/813.png  to ->  G
# From:  captcha/test_set/Q/1.png  to ->  U
# From:  captcha/test_set/Q/754.png  to ->  3
# From:  captcha/test_set/Q/797.png  to ->  D
# From:  captcha/test_set/Q/581.png  to ->  3
# From:  captcha/test_set/Q/580.png  to ->  3
# From:  captcha/test_set/Q/796.png  to ->  N
# From:  captcha/test_set/Q/741.png  to ->  D
# From:  captcha/test_set/Q/190.png  to ->  D
# From:  captcha/test_set/Q/609.png  to ->  J
# From:  captcha/test_set/Q/147.png  to ->  C
# From:  captcha/test_set/Q/423.png  to ->  D
# From:  captcha/test_set/Q/351.png  to ->  U
# From:  captcha/test_set/X/599.png  to ->  K
# From:  captcha/test_set/X/188.png  to ->  T
# From:  captcha/test_set/X/1144.png  to ->  K
# From:  captcha/test_set/X/388.png  to ->  K
# From:  captcha/test_set/X/1634.png  to ->  T
# From:  captcha/test_set/X/773.png  to ->  K
# From:  captcha/test_set/X/1219.png  to ->  R
# From:  captcha/test_set/X/1143.png  to ->  Y
# From:  captcha/test_set/X/1625.png  to ->  N
# From:  captcha/test_set/X/1156.png  to ->  2
# From:  captcha/test_set/X/371.png  to ->  K
# From:  captcha/test_set/X/629.png  to ->  T
# From:  captcha/test_set/X/1008.png  to ->  T
# From:  captcha/test_set/X/713.png  to ->  V
# From:  captcha/test_set/X/470.png  to ->  Y
# From:  captcha/test_set/X/458.png  to ->  K
# From:  captcha/test_set/X/1131.png  to ->  T
# From:  captcha/test_set/X/1050.png  to ->  R
# From:  captcha/test_set/X/1337.png  to ->  T
# From:  captcha/test_set/X/1689.png  to ->  T
# From:  captcha/test_set/X/651.png  to ->  T
# From:  captcha/test_set/X/888.png  to ->  2
# From:  captcha/test_set/X/1538.png  to ->  T
# From:  captcha/test_set/X/1666.png  to ->  K
# From:  captcha/test_set/X/325.png  to ->  K
# From:  captcha/test_set/X/1102.png  to ->  T
# From:  captcha/test_set/X/904.png  to ->  2
# From:  captcha/test_set/X/1011.png  to ->  K
# From:  captcha/test_set/X/197.png  to ->  N
# From:  captcha/test_set/X/586.png  to ->  T
# From:  captcha/test_set/X/790.png  to ->  K
